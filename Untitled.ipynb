# %%
import requests
import bs4

# %%
page = requests.get("https://www.ticketveiling.nl/dagjes-uit/outdoor-activiteiten/scooter-rijden-go-sharing-korting").text

# %%
page = bs4.BeautifulSoup(page)

# %%
print(page.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1" name="viewport"/>
#   <title>
#    GO Sharing rijminuten | Outdoor activiteiten | Ticketveiling.nl
#   </title>
#   <link href="/apple-touch-icon.png?v=rMBM2NQz8L" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/favicon-32x32.png?v=rMBM2NQz8L" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/favicon-16x16.png?v=rMBM2NQz8L" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/site.webmanifest?v=rMBM2NQz8L" rel="manifest"/>
#   <link color="#ff0078" href="/safari-pinned-tab.svg?v=rMBM2NQz8L" rel="mask-icon"/>
#   <link href="/favicon.ico?v=rMBM2NQz8L" rel="shortcut icon"/>
#   <meta content="#2b5797" name="msapplication-TileColor"/>
#   <meta content="#ffffff" name="theme-color"/>
# ...

# %%
len(page.find("div", attrs={'auction-detail': "auction-detail"}))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-0cd5383b51a7> in <module>
# ----> 1 len(page.find("div", attrs={'auction-detail': "auction-detail"}))
#
# TypeError: object of type 'NoneType' has no len()
